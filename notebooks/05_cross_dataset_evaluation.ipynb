# %% [markdown]
# # 05 Cross-Dataset Evaluation
#
# Train on SemEval and test on RAID, then train on RAID and test on SemEval.

# %%
# !python ../scripts/04_cross_dataset_evaluation.py

# %%
import pandas as pd
pd.read_csv("../outputs/results/cross_dataset_results.csv")
