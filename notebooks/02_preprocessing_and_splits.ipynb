# %% [markdown]
# # 02 Preprocessing and Splits
#
# Clean datasets and create consistent train/test splits.

# %%
# !python ../scripts/01_prepare_datasets.py --skip-raid-stream

# %%
# !python ../scripts/02_make_splits.py

# %% [markdown]
# If RAID should be streamed from Hugging Face, run the prepare script without `--skip-raid-stream` from the terminal.
