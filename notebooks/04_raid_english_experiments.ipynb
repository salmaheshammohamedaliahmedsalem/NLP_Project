# %% [markdown]
# # 04 RAID English Experiments
#
# Train M1-M4 on the RAID English subset and save results, models, errors, plots, and confusion matrices.

# %%
# !python ../scripts/03_run_english_experiments.py --dataset raid

# %%
import pandas as pd
pd.read_csv("../outputs/results/raid_results.csv")
