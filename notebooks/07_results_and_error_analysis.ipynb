# %% [markdown]
# # 07 Results and Error Analysis
#
# Load all result CSVs, create final tables and discuss cross-dataset drops and error patterns.

# %%
# !python ../scripts/06_build_reports.py

# %%
from pathlib import Path
for path in sorted(Path("../outputs/results").glob("*.csv")):
    print("\n", path.name)
    import pandas as pd
    display(pd.read_csv(path).head())

# %% [markdown]
# ## Discussion Prompts
#
# - Which model wins on SemEval?
# - Which model wins on RAID?
# - How much does F1 drop in cross-dataset evaluation?
# - Does M4 improve over M1-M3?
# - What errors are common for the hybrid model?
