# %% [markdown]
# # 06 Arabic Proof of Concept
#
# Run a small Arabic extension using Arabic-specific preprocessing. At minimum, compare M2 and M4.

# %%
# !python ../scripts/05_arabic_poc.py

# %%
import pandas as pd
from pathlib import Path
path = Path("../outputs/results/arabic_poc_results.csv")
if path.exists():
    display(pd.read_csv(path))
else:
    print("Arabic results not found yet.")
